# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Assignments\EDA1\EDA1\Cardiotocographic.csv")
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# change the raw data into the data frame

# %%
df=pd.DataFrame(data)

# %% [markdown]
# count the all null values in the data set

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# fill the null values in the data set with mean value and "inplace=True" replaces the all null values

# %%
df['LB'].fillna(df.LB.mean(),inplace=True)
df['AC'].fillna(df.AC.mean(),inplace=True)
df['DS'].fillna(df.DS.mean(),inplace=True)
df['DP'].fillna(df.DP.mean(),inplace=True)
df['MLTV'].fillna(df.MLTV.mean(),inplace=True)
df['Width'].fillna(df.Width.mean(),inplace=True)
df['Tendency'].fillna(df.Tendency.mean(),inplace=True)
df['NSP'].fillna(df.NSP.mean(),inplace=True)
# Out:
# C:\Users\gadeg\AppData\Local\Temp\ipykernel_9864\2426789637.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LB'].fillna(df.LB.mean(),inplace=True)
# C:\Users\gadeg\AppData\Local\Temp\ipykernel_9864\2426789637.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# To know the all columns data types

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %% [markdown]
# Find all numerical values in data set

# %%
numerical=df.describe()
print(numerical)
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %% [markdown]
# Box plot is used to identify the out layers

# %%
fig, box=plt.subplots(5,3, figsize=(11,26))

(df['LB']).plot(kind='box', ax=box[0,0])
box[0,0].set_title('LB')

(df['AC']).plot(kind='box', ax=box[0,1])
box[0,1].set_title('AC')

(df['FM']).plot(kind='box', ax=box[0,2])
box[0,2].set_title('FM')

(df['UC']).plot(kind='box', ax=box[1,0])
box[1,0].set_title('UC')

(df['DL']).plot(kind='box', ax=box[1,1])
box[1,1].set_title('DL')

(df['DS']).plot(kind='box', ax=box[1,2])
box[1,2].set_title('DS')

(df['DP']).plot(kind='box', ax=box[2,0])
box[2,0].set_title('DP')

(df['ASTV']).plot(kind='box', ax=box[2,1])
box[2,1].set_title('ASTV')

(df['MSTV']).plot(kind='box', ax=box[2,2])
box[2,2].set_title('MSTV')

(df['ALTV']).plot(kind='box', ax=box[3,0])
box[3,0].set_title('ALTV')

(df['MLTV']).plot(kind='box', ax=box[3,1])
box[3,1].set_title('MLTV')

(df['Width']).plot(kind='box', ax=box[3,2])
box[3,2].set_title('Width')

(df['Tendency']).plot(kind='box', ax=box[4,0])
box[4,0].set_title('Tendency')

(df['NSP']).plot(kind='box', ax=box[4,1])
box[4,1].set_title('NSP')

fig.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df.mean()
# Out:
# LB          133.343598
# AC            0.003219
# FM            0.009894
# UC            0.004391
# DL            0.001895
# DS            0.000003
# DP            0.000175
# ASTV         46.995984
# MSTV          1.364378
# ALTV         10.285964
# MLTV          8.284887
# Width        70.429260
# Tendency      0.316371
# NSP           1.304507
# dtype: float64

# %%
df.median()
# Out:
# LB          133.000000
# AC            0.001668
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.500000
# Width        68.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
df.std()
# Out:
# LB          11.214328
# AC           0.004370
# FM           0.067540
# UC           0.003340
# DL           0.003343
# DS           0.000141
# DP           0.000836
# ASTV        18.813973
# MSTV         1.173632
# ALTV        21.205041
# MLTV         7.734356
# Width       42.719161
# Tendency     0.642424
# NSP          0.641426
# dtype: float64

# %% [markdown]
# Co-relaction between two numerical columns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Used in the distribution variables

# %%
plt.hist(x='LB',data=df)
plt.show()

# %%
plt.hist(x='AC',data=df)
# Out:
# (array([   4.,    0.,    0., 1401.,  550.,  151.,   14.,    0.,    0.,
#            6.]),
#  array([-0.01928375, -0.01349862, -0.0077135 , -0.00192837,  0.00385675,
#          0.00964187,  0.015427  ,  0.02121212,  0.02699725,  0.03278237,
#          0.03856749]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x='ASTV',data=df)
# Out:
# (array([  5.,   0.,   0., 336., 740., 891., 149.,   0.,   0.,   5.]),
#  array([-63. , -40.5, -18. ,   4.5,  27. ,  49.5,  72. ,  94.5, 117. ,
#         139.5, 162. ]),
#  <BarContainer object of 10 artists>)
